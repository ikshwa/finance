# %%
import pandas as pd
import numpy as np
import math 
import seaborn as sns 
import matplotlib.pyplot as plt
#from sklearn import metrics
#from sklearn.model_selection import train_test_split
import yfinance as yf  # We will use this library to upload latest data from Yahoo API
# %matplotlib inline
plt.style.use('fivethirtyeight')
print("All imported")
# Out:
# All imported

# %%
aru = yf.Ticker('ARU.AX')
#Display stock information, it will give you a summary description of the ticker
history = aru.history(period="Max")
df = pd.DataFrame(history)
df.head(10)
# Out:
#                                Open      High       Low     Close  Volume  \
# Date
# 2003-11-05 00:00:00+11:00  0.200795  0.200795  0.178482  0.178482  823593
# 2003-11-06 00:00:00+11:00  0.178482  0.178482  0.151717  0.160639  228028
# 2003-11-07 00:00:00+11:00  0.178482  0.178482  0.169560  0.169560   35856
# 2003-11-10 00:00:00+11:00  0.178482  0.178482  0.160639  0.160639   61629
# 2003-11-11 00:00:00+11:00  0.160639  0.160639  0.142787  0.142787  150151
# 2003-11-12 00:00:00+11:00  0.151717  0.151717  0.142787  0.147248  139113
# 2003-11-13 00:00:00+11:00  0.147248  0.151717  0.147248  0.151717  158275
# 2003-11-14 00:00:00+11:00  0.151717  0.151717  0.142787  0.142787   95805
# 2003-11-17 00:00:00+11:00  0.142787  0.142787  0.142787  0.142787   94685
# 2003-11-18 00:00:00+11:00  0.142787  0.142787  0.142787  0.142787   47622
#
#                            Dividends  Stock Splits
# Date
# 2003-11-05 00:00:00+11:00        0.0           0.0
# 2003-11-06 00:00:00+11:00        0.0           0.0
# 2003-11-07 00:00:00+11:00        0.0           0.0
# 2003-11-10 00:00:00+11:00        0.0           0.0
# 2003-11-11 00:00:00+11:00        0.0           0.0
# 2003-11-12 00:00:00+11:00        0.0           0.0
# 2003-11-13 00:00:00+11:00        0.0           0.0
# 2003-11-14 00:00:00+11:00        0.0           0.0
# 2003-11-17 00:00:00+11:00        0.0           0.0
# 2003-11-18 00:00:00+11:00        0.0           0.0

# %%
x = df.index
y = df['Close']

# %%
def df_plot(data, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

# %%
stock_name= "ARU.AX"
title = (stock_name,"History stock performance till date")
df_plot(df , x , y , title=title,xlabel='Date', ylabel='Value',dpi=100)

# %%
df.reset_index()
# Out:
#                                Open      High       Low     Close  Volume  \
# Date
# 2003-11-05 00:00:00+11:00  0.200795  0.200795  0.178482  0.178482  823593
# 2003-11-06 00:00:00+11:00  0.178482  0.178482  0.151717  0.160639  228028
#
#                            Dividends  Stock Splits
# Date
# 2003-11-05 00:00:00+11:00        0.0           0.0
# 2003-11-06 00:00:00+11:00        0.0           0.0

# %%
df.drop(columns=['Dividends','Stock Splits']).head(2)
# Out:
#                        Date      Open      High       Low     Close  Volume
# 0 2003-11-05 00:00:00+11:00  0.200795  0.200795  0.178482  0.178482  823593
# 1 2003-11-06 00:00:00+11:00  0.178482  0.178482  0.151717  0.160639  228028

# %%
df['date'] = pd.to_datetime(df.Date)
df.describeribe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df['date'] = pd.to_datetime(df.date)
#       2 df.describeribe()
#
# File ~\Anaconda3\envs\py39\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'date'
