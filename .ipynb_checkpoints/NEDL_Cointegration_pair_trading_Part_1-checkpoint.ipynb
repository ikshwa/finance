# %%
#importing packages
import numpy as np
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
import scipy.optimize as spop
import matplotlib.pyplot as plt

# %%
#specifying parameters
stocks = ['BHP','RIO']
start = '2022-04-25'
end = '2023-06-13'
fee = 0.001
window = 252
t_threshold = -2.5
#retrieving data
data = pd.DataFrame()
returns = pd.DataFrame()
for stock in stocks:
    prices = yf.download(stock, start, end)
    data[stock] = prices['Close']
    returns[stock] = np.append(data[stock][1:].reset_index(drop=True)/data[stock][:-1].reset_index(drop=True) - 1 , 0)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
#initialising arrays
gross_returns = np.array([])
net_returns = np.array([])
t_s = np.array([])
stock1 = stocks[0]
stock2 = stocks[1]
#moving through the sample
for t in range(window, len(data)):
    #defining the unit root function: stock2 = a + b*stock1
    def unit_root(b):
        a = np.average(data[stock2][t-window:t] - b*data[stock1][t-window:t])
        fair_value = a + b*data[stock1][t-window:t]
        diff = np.array(fair_value - data[stock2][t-window:t])
        diff_diff = diff[1:] - diff[:-1]
        reg = sm.OLS(diff_diff, diff[:-1])
        res = reg.fit()
        return res.params[0]/res.bse[0]
    #optimising the cointegration equation parameters
    res1 = spop.minimize(unit_root, data[stock2][t]/data[stock1][t], method='Nelder-Mead')
    t_opt = res1.fun
    b_opt = float(res1.x)
    a_opt = np.average(data[stock2][t-window:t] - b_opt*data[stock1][t-window:t])
    #simulating trading
    fair_value = a_opt + b_opt*data[stock1][t]
    if t == window:
        old_signal = 0
    if t_opt > t_threshold:
        signal = 0
        gross_return = 0
    else:
        signal = np.sign(fair_value - data[stock2][t])
        gross_return = signal*returns[stock2][t] - signal*returns[stock1][t]
    fees = fee*abs(signal - old_signal)
    net_return = gross_return - fees
    gross_returns = np.append(gross_returns, gross_return)
    net_returns = np.append(net_returns, net_return)
    t_s = np.append(t_s, t_opt)
    # interface: reporting daily positions and realised returns
    print('day '+str(data.index[t]))
    print('')
    if signal == 0:
        print('no trading')
    elif  signal == 1:
        print('long position on '+stock2+' and short position on '+stock1)
    else:
        print('long position on '+stock1+' and short position on '+stock2)
    print('gross daily return: '+str(round(gross_return*100,2))+'%')
    print('net daily return: '+str(round(net_return*100,2))+'%')
    print('cumulative net return so far: '+str(round(np.prod(1+net_returns)*100-100,2))+'%')
    print('')
    old_signal = signal
#plotting equity curves
# plt.plot(np.append(1,np.cumprod(1+gross_returns)))
plt.plot(np.append(1,np.cumprod(1+net_returns)))
# Out:
# day 2021-04-27 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.79%
# net daily return: 0.69%
# cumulative net return so far: 0.69%
#
# day 2021-04-28 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -1.22%
# net daily return: -1.22%
# cumulative net return so far: -0.54%
#
# day 2021-04-29 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.13%
# net daily return: 0.13%
# cumulative net return so far: -0.4%
#
# day 2021-04-30 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.37%
# net daily return: -0.37%
# cumulative net return so far: -0.77%
#
# day 2021-05-03 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.38%
# net daily return: 0.38%
# cumulative net return so far: -0.39%
#
# day 2021-05-04 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.17%
# net daily return: -0.17%
# cumulative net return so far: -0.56%
#
# day 2021-05-05 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.43%
# net daily return: 0.43%
# cumulative net return so far: -0.13%
#
# day 2021-05-06 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.69%
# net daily return: -0.69%
# cumulative net return so far: -0.82%
#
# day 2021-05-07 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.14%
# net daily return: 1.14%
# cumulative net return so far: 0.31%
#
# day 2021-05-10 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -1.06%
# net daily return: -1.06%
# cumulative net return so far: -0.75%
#
# day 2021-05-11 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.04%
# net daily return: -0.04%
# cumulative net return so far: -0.79%
#
# day 2021-05-12 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.2%
# net daily return: 1.2%
# cumulative net return so far: 0.4%
#
# day 2021-05-13 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.73%
# net daily return: 1.73%
# cumulative net return so far: 2.14%
#
# day 2021-05-14 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.13%
# net daily return: 0.93%
# cumulative net return so far: 3.09%
#
# day 2021-05-17 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.21%
# net daily return: -0.41%
# cumulative net return so far: 2.67%
#
# day 2021-05-18 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.74%
# net daily return: -0.74%
# cumulative net return so far: 1.9%
#
# day 2021-05-19 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.46%
# net daily return: -0.46%
# cumulative net return so far: 1.43%
#
# day 2021-05-20 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.08%
# net daily return: 0.08%
# cumulative net return so far: 1.51%
#
# day 2021-05-21 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.47%
# net daily return: -0.47%
# cumulative net return so far: 1.03%
#
# day 2021-05-24 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: 1.35%
#
# day 2021-05-25 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.09%
# net daily return: -0.09%
# cumulative net return so far: 1.26%
#
# day 2021-05-26 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -1.01%
# net daily return: -1.01%
# cumulative net return so far: 0.24%
#
# day 2021-05-27 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.18%
# net daily return: 0.18%
# cumulative net return so far: 0.42%
#
# day 2021-05-28 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.9%
# net daily return: -0.9%
# cumulative net return so far: -0.49%
#
# day 2021-06-01 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.57%
# net daily return: 0.57%
# cumulative net return so far: 0.08%
#
# day 2021-06-02 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.19%
# net daily return: 0.19%
# cumulative net return so far: 0.27%
#
# day 2021-06-03 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.16%
# net daily return: 0.16%
# cumulative net return so far: 0.43%
#
# day 2021-06-04 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.12%
# net daily return: 0.12%
# cumulative net return so far: 0.56%
#
# day 2021-06-07 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.02%
# net daily return: 1.02%
# cumulative net return so far: 1.58%
#
# day 2021-06-08 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.13%
# net daily return: -0.13%
# cumulative net return so far: 1.45%
#
# day 2021-06-09 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.08%
# net daily return: 1.08%
# cumulative net return so far: 2.55%
#
# day 2021-06-10 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.16%
# net daily return: 0.16%
# cumulative net return so far: 2.71%
#
# day 2021-06-11 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.08%
# net daily return: 0.08%
# cumulative net return so far: 2.79%
#
# day 2021-06-14 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.12%
# net daily return: -0.12%
# cumulative net return so far: 2.67%
#
# day 2021-06-15 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.57%
# net daily return: 0.57%
# cumulative net return so far: 3.25%
#
# day 2021-06-16 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 2.56%
# net daily return: 2.36%
# cumulative net return so far: 5.69%
#
# day 2021-06-17 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.4%
# net daily return: -0.6%
# cumulative net return so far: 5.06%
#
# day 2021-06-18 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.46%
# net daily return: 1.46%
# cumulative net return so far: 6.59%
#
# day 2021-06-21 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.04%
# net daily return: -0.04%
# cumulative net return so far: 6.56%
#
# day 2021-06-22 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: 6.28%
#
# day 2021-06-23 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: 6.62%
#
# day 2021-06-24 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.37%
# net daily return: 0.37%
# cumulative net return so far: 7.02%
#
# day 2021-06-25 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.09%
# net daily return: 0.09%
# cumulative net return so far: 7.11%
#
# day 2021-06-28 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.16%
# net daily return: -0.16%
# cumulative net return so far: 6.93%
#
# day 2021-06-29 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.86%
# net daily return: 0.86%
# cumulative net return so far: 7.86%
#
# day 2021-06-30 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.82%
# net daily return: 0.82%
# cumulative net return so far: 8.74%
#
# day 2021-07-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.34%
# net daily return: 0.14%
# cumulative net return so far: 8.89%
#
# day 2021-07-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.49%
# net daily return: -0.49%
# cumulative net return so far: 8.36%
#
# day 2021-07-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.13%
# net daily return: -0.13%
# cumulative net return so far: 8.22%
#
# day 2021-07-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.48%
# net daily return: -1.48%
# cumulative net return so far: 6.62%
#
# day 2021-07-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.2%
# net daily return: 0.2%
# cumulative net return so far: 6.83%
#
# day 2021-07-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.01%
# net daily return: 0.01%
# cumulative net return so far: 6.84%
#
# day 2021-07-12 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.56%
# net daily return: -0.56%
# cumulative net return so far: 6.25%
#
# day 2021-07-13 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.8%
# net daily return: 0.8%
# cumulative net return so far: 7.1%
#
# day 2021-07-14 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.23%
# net daily return: 0.23%
# cumulative net return so far: 7.34%
#
# day 2021-07-15 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.43%
# net daily return: -1.43%
# cumulative net return so far: 5.8%
#
# day 2021-07-16 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.35%
# net daily return: -0.35%
# cumulative net return so far: 5.43%
#
# day 2021-07-19 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.54%
# net daily return: -0.54%
# cumulative net return so far: 4.87%
#
# day 2021-07-20 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.76%
# net daily return: -0.76%
# cumulative net return so far: 4.07%
#
# day 2021-07-21 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.89%
# net daily return: -0.89%
# cumulative net return so far: 3.14%
#
# day 2021-07-22 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.22%
# net daily return: -0.22%
# cumulative net return so far: 2.92%
#
# day 2021-07-23 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.56%
# net daily return: 0.56%
# cumulative net return so far: 3.5%
#
# day 2021-07-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -2.53%
# net daily return: -2.53%
# cumulative net return so far: 0.87%
#
# day 2021-07-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 3.25%
# net daily return: 3.25%
# cumulative net return so far: 4.16%
#
# day 2021-07-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: 4.05%
#
# day 2021-07-29 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.57%
# net daily return: -0.67%
# cumulative net return so far: 3.36%
#
# day 2021-07-30 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.34%
# net daily return: 1.34%
# cumulative net return so far: 4.74%
#
# day 2021-08-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.71%
# net daily return: 0.71%
# cumulative net return so far: 5.48%
#
# day 2021-08-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.07%
# net daily return: -0.07%
# cumulative net return so far: 5.41%
#
# day 2021-08-04 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.75%
# net daily return: -1.75%
# cumulative net return so far: 3.56%
#
# day 2021-08-05 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.66%
# net daily return: 0.66%
# cumulative net return so far: 4.25%
#
# day 2021-08-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.94%
# net daily return: 0.94%
# cumulative net return so far: 5.23%
#
# day 2021-08-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.31%
# net daily return: 0.31%
# cumulative net return so far: 5.55%
#
# day 2021-08-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.4%
# net daily return: -1.4%
# cumulative net return so far: 4.07%
#
# day 2021-08-11 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -6.67%
# net daily return: -6.67%
# cumulative net return so far: -2.87%
#
# day 2021-08-12 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.99%
# net daily return: -0.99%
# cumulative net return so far: -3.83%
#
# day 2021-08-13 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.8%
# net daily return: 0.8%
# cumulative net return so far: -3.07%
#
# day 2021-08-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -3.17%
#
# day 2021-08-17 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 2.73%
# net daily return: 2.63%
# cumulative net return so far: -0.62%
#
# day 2021-08-18 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.71%
# net daily return: 1.71%
# cumulative net return so far: 1.08%
#
# day 2021-08-19 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.07%
# net daily return: 0.87%
# cumulative net return so far: 1.96%
#
# day 2021-08-20 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.64%
# net daily return: -0.84%
# cumulative net return so far: 1.1%
#
# day 2021-08-23 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.62%
# net daily return: 1.62%
# cumulative net return so far: 2.74%
#
# day 2021-08-24 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.51%
# net daily return: 0.31%
# cumulative net return so far: 3.06%
#
# day 2021-08-25 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.31%
# net daily return: -0.51%
# cumulative net return so far: 2.53%
#
# day 2021-08-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.25%
# net daily return: -0.25%
# cumulative net return so far: 2.27%
#
# day 2021-08-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.33%
# net daily return: -1.33%
# cumulative net return so far: 0.9%
#
# day 2021-08-30 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.96%
# net daily return: 0.96%
# cumulative net return so far: 1.87%
#
# day 2021-08-31 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.09%
# net daily return: 1.09%
# cumulative net return so far: 2.98%
#
# day 2021-09-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 5.7%
# net daily return: 5.7%
# cumulative net return so far: 8.85%
#
# day 2021-09-02 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.04%
# net daily return: 0.84%
# cumulative net return so far: 9.77%
#
# day 2021-09-03 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.04%
# net daily return: 0.04%
# cumulative net return so far: 9.82%
#
# day 2021-09-07 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.18%
# net daily return: -0.18%
# cumulative net return so far: 9.62%
#
# day 2021-09-08 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.09%
# net daily return: 1.09%
# cumulative net return so far: 10.82%
#
# day 2021-09-09 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.84%
# net daily return: -0.84%
# cumulative net return so far: 9.88%
#
# day 2021-09-10 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.44%
# net daily return: -0.44%
# cumulative net return so far: 9.4%
#
# day 2021-09-13 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.62%
# net daily return: -0.62%
# cumulative net return so far: 8.72%
#
# day 2021-09-14 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.35%
# net daily return: -0.35%
# cumulative net return so far: 8.35%
#
# day 2021-09-15 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.99%
# net daily return: 0.99%
# cumulative net return so far: 9.42%
#
# day 2021-09-16 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -1.43%
# net daily return: -1.43%
# cumulative net return so far: 7.85%
#
# day 2021-09-17 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.19%
# net daily return: 0.19%
# cumulative net return so far: 8.06%
#
# day 2021-09-20 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.98%
# net daily return: 1.98%
# cumulative net return so far: 10.21%
#
# day 2021-09-21 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -1.02%
# net daily return: -1.02%
# cumulative net return so far: 9.08%
#
# day 2021-09-22 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.6%
# net daily return: -0.6%
# cumulative net return so far: 8.43%
#
# day 2021-09-23 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.53%
# net daily return: -0.53%
# cumulative net return so far: 7.85%
#
# day 2021-09-24 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.16%
# net daily return: -0.16%
# cumulative net return so far: 7.68%
#
# day 2021-09-27 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -2.03%
# net daily return: -2.03%
# cumulative net return so far: 5.5%
#
# day 2021-09-28 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.25%
# net daily return: 0.25%
# cumulative net return so far: 5.76%
#
# day 2021-09-29 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.07%
# net daily return: 0.07%
# cumulative net return so far: 5.83%
#
# day 2021-09-30 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.07%
# net daily return: 0.07%
# cumulative net return so far: 5.91%
#
# day 2021-10-01 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.02%
# net daily return: 0.02%
# cumulative net return so far: 5.93%
#
# day 2021-10-04 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.14%
# net daily return: 0.14%
# cumulative net return so far: 6.08%
#
# day 2021-10-05 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.18%
# net daily return: -0.18%
# cumulative net return so far: 5.89%
#
# day 2021-10-06 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.28%
# net daily return: -0.28%
# cumulative net return so far: 5.59%
#
# day 2021-10-07 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.62%
# net daily return: 0.62%
# cumulative net return so far: 6.25%
#
# day 2021-10-08 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.54%
# net daily return: -0.54%
# cumulative net return so far: 5.68%
#
# day 2021-10-11 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.82%
# net daily return: 0.82%
# cumulative net return so far: 6.54%
#
# day 2021-10-12 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.24%
# net daily return: -0.24%
# cumulative net return so far: 6.28%
#
# day 2021-10-13 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.83%
# net daily return: 0.83%
# cumulative net return so far: 7.16%
#
# day 2021-10-14 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.63%
# net daily return: 0.63%
# cumulative net return so far: 7.84%
#
# day 2021-10-15 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.28%
# net daily return: 1.28%
# cumulative net return so far: 9.21%
#
# day 2021-10-18 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.89%
# net daily return: -0.89%
# cumulative net return so far: 8.24%
#
# day 2021-10-19 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 3.77%
# net daily return: 3.77%
# cumulative net return so far: 12.32%
#
# day 2021-10-20 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.22%
# net daily return: -0.42%
# cumulative net return so far: 11.86%
#
# day 2021-10-21 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.89%
# net daily return: -0.89%
# cumulative net return so far: 10.86%
#
# day 2021-10-22 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.17%
# net daily return: 0.17%
# cumulative net return so far: 11.05%
#
# day 2021-10-25 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: 10.76%
#
# day 2021-10-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.42%
# net daily return: -0.42%
# cumulative net return so far: 10.29%
#
# day 2021-10-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.52%
# net daily return: -0.52%
# cumulative net return so far: 9.73%
#
# day 2021-10-28 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.36%
# net daily return: 0.36%
# cumulative net return so far: 10.12%
#
# day 2021-10-29 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.81%
# net daily return: 0.81%
# cumulative net return so far: 11.01%
#
# day 2021-11-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.28%
# net daily return: 0.28%
# cumulative net return so far: 11.32%
#
# day 2021-11-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.89%
# net daily return: -0.89%
# cumulative net return so far: 10.33%
#
# day 2021-11-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.01%
# net daily return: -1.01%
# cumulative net return so far: 9.21%
#
# day 2021-11-04 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.85%
# net daily return: -0.85%
# cumulative net return so far: 8.29%
#
# day 2021-11-05 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.34%
# net daily return: 0.34%
# cumulative net return so far: 8.66%
#
# day 2021-11-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.97%
# net daily return: 0.97%
# cumulative net return so far: 9.71%
#
# day 2021-11-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.3%
# net daily return: 0.3%
# cumulative net return so far: 10.03%
#
# day 2021-11-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.83%
# net daily return: -0.83%
# cumulative net return so far: 9.12%
#
# day 2021-11-11 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.07%
# net daily return: -0.07%
# cumulative net return so far: 9.05%
#
# day 2021-11-12 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.28%
# net daily return: 0.28%
# cumulative net return so far: 9.35%
#
# day 2021-11-15 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.12%
# net daily return: 0.12%
# cumulative net return so far: 9.49%
#
# day 2021-11-16 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.99%
# net daily return: 0.99%
# cumulative net return so far: 10.57%
#
# day 2021-11-17 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.23%
# net daily return: -1.23%
# cumulative net return so far: 9.21%
#
# day 2021-11-18 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.24%
# net daily return: 1.24%
# cumulative net return so far: 10.56%
#
# day 2021-11-19 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.03%
# net daily return: -1.03%
# cumulative net return so far: 9.43%
#
# day 2021-11-22 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.16%
# net daily return: 0.16%
# cumulative net return so far: 9.6%
#
# day 2021-11-23 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.05%
# net daily return: -0.05%
# cumulative net return so far: 9.54%
#
# day 2021-11-24 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.33%
# net daily return: -0.33%
# cumulative net return so far: 9.17%
#
# day 2021-11-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.83%
# net daily return: -1.83%
# cumulative net return so far: 7.17%
#
# day 2021-11-29 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.81%
# net daily return: -0.81%
# cumulative net return so far: 6.31%
#
# day 2021-11-30 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.79%
# net daily return: 0.79%
# cumulative net return so far: 7.15%
#
# day 2021-12-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.15%
# net daily return: -1.15%
# cumulative net return so far: 5.91%
#
# day 2021-12-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.1%
# net daily return: 1.1%
# cumulative net return so far: 7.07%
#
# day 2021-12-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.18%
# net daily return: -1.18%
# cumulative net return so far: 5.81%
#
# day 2021-12-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.27%
# net daily return: -0.27%
# cumulative net return so far: 5.53%
#
# day 2021-12-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.09%
# net daily return: -0.09%
# cumulative net return so far: 5.43%
#
# day 2021-12-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.16%
# net daily return: 1.16%
# cumulative net return so far: 6.66%
#
# day 2021-12-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.04%
# net daily return: -0.04%
# cumulative net return so far: 6.61%
#
# day 2021-12-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.6%
# net daily return: -0.6%
# cumulative net return so far: 5.98%
#
# day 2021-12-13 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.02%
# net daily return: -0.02%
# cumulative net return so far: 5.96%
#
# day 2021-12-14 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.54%
# net daily return: -0.54%
# cumulative net return so far: 5.38%
#
# day 2021-12-15 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.61%
# net daily return: 1.61%
# cumulative net return so far: 7.08%
#
# day 2021-12-16 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.04%
# net daily return: -1.04%
# cumulative net return so far: 5.96%
#
# day 2021-12-17 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.81%
# net daily return: -0.81%
# cumulative net return so far: 5.11%
#
# day 2021-12-20 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.05%
# net daily return: 0.05%
# cumulative net return so far: 5.16%
#
# day 2021-12-21 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.57%
# net daily return: 0.57%
# cumulative net return so far: 5.76%
#
# day 2021-12-22 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.63%
# net daily return: -0.63%
# cumulative net return so far: 5.1%
#
# day 2021-12-23 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.32%
# net daily return: -0.32%
# cumulative net return so far: 4.77%
#
# day 2021-12-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.37%
# net daily return: 0.37%
# cumulative net return so far: 5.16%
#
# day 2021-12-28 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.69%
# net daily return: -0.69%
# cumulative net return so far: 4.44%
#
# day 2021-12-29 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.9%
# net daily return: 0.9%
# cumulative net return so far: 5.38%
#
# day 2021-12-30 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.11%
# net daily return: 0.11%
# cumulative net return so far: 5.49%
#
# day 2021-12-31 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.3%
# net daily return: -0.3%
# cumulative net return so far: 5.17%
#
# day 2022-01-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.44%
# net daily return: -0.44%
# cumulative net return so far: 4.71%
#
# day 2022-01-04 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.57%
# net daily return: 0.57%
# cumulative net return so far: 5.31%
#
# day 2022-01-05 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.82%
# net daily return: 1.82%
# cumulative net return so far: 7.23%
#
# day 2022-01-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.46%
# net daily return: -0.46%
# cumulative net return so far: 6.73%
#
# day 2022-01-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 2.53%
# net daily return: 2.53%
# cumulative net return so far: 9.43%
#
# day 2022-01-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.23%
# net daily return: 0.23%
# cumulative net return so far: 9.68%
#
# day 2022-01-11 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.91%
# net daily return: 1.71%
# cumulative net return so far: 11.56%
#
# day 2022-01-12 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.46%
# net daily return: -0.66%
# cumulative net return so far: 10.81%
#
# day 2022-01-13 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.15%
# net daily return: -0.15%
# cumulative net return so far: 10.65%
#
# day 2022-01-14 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.21%
# net daily return: 1.21%
# cumulative net return so far: 11.99%
#
# day 2022-01-18 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.16%
# net daily return: -0.16%
# cumulative net return so far: 11.81%
#
# day 2022-01-19 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.6%
# net daily return: -1.6%
# cumulative net return so far: 10.02%
#
# day 2022-01-20 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 2.13%
# net daily return: 2.13%
# cumulative net return so far: 12.37%
#
# day 2022-01-21 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.91%
# net daily return: -0.91%
# cumulative net return so far: 11.34%
#
# day 2022-01-24 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.69%
# net daily return: 1.69%
# cumulative net return so far: 13.22%
#
# day 2022-01-25 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.45%
# net daily return: 0.25%
# cumulative net return so far: 13.51%
#
# day 2022-01-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.63%
# net daily return: -0.83%
# cumulative net return so far: 12.56%
#
# day 2022-01-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.13%
# net daily return: -0.13%
# cumulative net return so far: 12.41%
#
# day 2022-01-28 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.48%
# net daily return: -1.48%
# cumulative net return so far: 10.75%
#
# day 2022-01-31 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.69%
# net daily return: 1.69%
# cumulative net return so far: 12.62%
#
# day 2022-02-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.65%
# net daily return: -0.65%
# cumulative net return so far: 11.89%
#
# day 2022-02-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.44%
# net daily return: -1.44%
# cumulative net return so far: 10.28%
#
# day 2022-02-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.07%
# net daily return: -0.07%
# cumulative net return so far: 10.21%
#
# day 2022-02-04 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.26%
# net daily return: 0.26%
# cumulative net return so far: 10.49%
#
# day 2022-02-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.87%
# net daily return: 0.87%
# cumulative net return so far: 11.45%
#
# day 2022-02-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.67%
# net daily return: 0.67%
# cumulative net return so far: 12.2%
#
# day 2022-02-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.71%
# net daily return: -0.71%
# cumulative net return so far: 11.41%
#
# day 2022-02-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.01%
# net daily return: -0.01%
# cumulative net return so far: 11.4%
#
# day 2022-02-11 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.69%
# net daily return: 1.69%
# cumulative net return so far: 13.28%
#
# day 2022-02-14 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.5%
# net daily return: 0.3%
# cumulative net return so far: 13.62%
#
# day 2022-02-15 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.06%
# net daily return: -0.14%
# cumulative net return so far: 13.46%
#
# day 2022-02-16 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.21%
# net daily return: 1.01%
# cumulative net return so far: 14.61%
#
# day 2022-02-17 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.85%
# net daily return: -1.05%
# cumulative net return so far: 13.41%
#
# day 2022-02-18 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.05%
# net daily return: 1.05%
# cumulative net return so far: 14.59%
#
# day 2022-02-22 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.38%
# net daily return: -0.38%
# cumulative net return so far: 14.16%
#
# day 2022-02-23 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 4.97%
# net daily return: 4.97%
# cumulative net return so far: 19.83%
#
# day 2022-02-24 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 2.24%
# net daily return: 2.04%
# cumulative net return so far: 22.27%
#
# day 2022-02-25 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.29%
# net daily return: 0.29%
# cumulative net return so far: 22.63%
#
# day 2022-02-28 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.8%
# net daily return: -0.8%
# cumulative net return so far: 21.65%
#
# day 2022-03-01 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.68%
# net daily return: 0.68%
# cumulative net return so far: 22.48%
#
# day 2022-03-02 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.88%
# net daily return: 0.88%
# cumulative net return so far: 23.56%
#
# day 2022-03-03 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 2.69%
# net daily return: 2.69%
# cumulative net return so far: 26.88%
#
# day 2022-03-04 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.87%
# net daily return: -2.07%
# cumulative net return so far: 24.25%
#
# day 2022-03-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.38%
# net daily return: 1.38%
# cumulative net return so far: 25.97%
#
# day 2022-03-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.14%
# net daily return: -0.14%
# cumulative net return so far: 25.79%
#
# day 2022-03-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -5.65%
# net daily return: -5.65%
# cumulative net return so far: 18.67%
#
# day 2022-03-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.89%
# net daily return: 0.89%
# cumulative net return so far: 19.73%
#
# day 2022-03-11 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.14%
# net daily return: -0.14%
# cumulative net return so far: 19.56%
#
# day 2022-03-14 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.67%
# net daily return: 0.67%
# cumulative net return so far: 20.36%
#
# day 2022-03-15 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 2.09%
# net daily return: 2.09%
# cumulative net return so far: 22.87%
#
# day 2022-03-16 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.33%
# net daily return: 1.33%
# cumulative net return so far: 24.5%
#
# day 2022-03-17 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.54%
# net daily return: -0.54%
# cumulative net return so far: 23.84%
#
# day 2022-03-18 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.13%
# net daily return: -1.13%
# cumulative net return so far: 22.43%
#
# day 2022-03-21 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.72%
# net daily return: -0.72%
# cumulative net return so far: 21.55%
#
# day 2022-03-22 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.87%
# net daily return: -0.87%
# cumulative net return so far: 20.49%
#
# day 2022-03-23 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.26%
# net daily return: -1.26%
# cumulative net return so far: 18.98%
#
# day 2022-03-24 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.12%
# net daily return: 0.12%
# cumulative net return so far: 19.12%
#
# day 2022-03-25 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.58%
# net daily return: -1.58%
# cumulative net return so far: 17.24%
#
# day 2022-03-28 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.24%
# net daily return: -0.24%
# cumulative net return so far: 16.95%
#
# day 2022-03-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: 16.84%
#
# day 2022-03-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-03-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-04-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-05-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-05-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-05-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-05-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 16.84%
#
# day 2022-05-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.08%
# net daily return: 0.98%
# cumulative net return so far: 17.98%
#
# day 2022-05-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: 17.86%
#
# day 2022-05-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 17.86%
#
# day 2022-05-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -2.35%
# net daily return: -2.45%
# cumulative net return so far: 14.98%
#
# day 2022-05-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.85%
# net daily return: 0.85%
# cumulative net return so far: 15.96%
#
# day 2022-05-31 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.62%
# net daily return: -1.62%
# cumulative net return so far: 14.08%
#
# day 2022-06-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -2.05%
# net daily return: -2.05%
# cumulative net return so far: 11.74%
#
# day 2022-06-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.76%
# net daily return: -0.76%
# cumulative net return so far: 10.89%
#
# day 2022-06-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.88%
# net daily return: 1.88%
# cumulative net return so far: 12.98%
#
# day 2022-06-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.36%
# net daily return: -0.36%
# cumulative net return so far: 12.57%
#
# day 2022-06-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.1%
# net daily return: -0.1%
# cumulative net return so far: 12.46%
#
# day 2022-06-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.7%
# net daily return: 0.7%
# cumulative net return so far: 13.25%
#
# day 2022-06-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.9%
# net daily return: -0.9%
# cumulative net return so far: 12.23%
#
# day 2022-06-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.19%
# net daily return: 0.19%
# cumulative net return so far: 12.44%
#
# day 2022-06-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: 12.33%
#
# day 2022-06-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-06-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-07-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 12.33%
#
# day 2022-08-01 00:00:00
#
# no trading
# gross daily return: 0%
# ...
# gross daily return: 0.53%
# net daily return: 0.53%
# cumulative net return so far: 14.86%
#
# day 2023-01-20 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.6%
# net daily return: 0.6%
# cumulative net return so far: 15.54%
#
# day 2023-01-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: 15.43%
#
# day 2023-01-24 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.31%
# net daily return: -0.41%
# cumulative net return so far: 14.96%
#
# day 2023-01-25 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.03%
# net daily return: -0.03%
# cumulative net return so far: 14.93%
#
# day 2023-01-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.93%
# net daily return: 0.93%
# cumulative net return so far: 15.99%
#
# day 2023-01-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.55%
# net daily return: -0.55%
# cumulative net return so far: 15.35%
#
# day 2023-01-30 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.16%
# net daily return: -0.16%
# cumulative net return so far: 15.17%
#
# day 2023-01-31 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: 14.87%
#
# day 2023-02-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.34%
# net daily return: -1.34%
# cumulative net return so far: 13.33%
#
# day 2023-02-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.11%
# net daily return: 0.11%
# cumulative net return so far: 13.46%
#
# day 2023-02-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.47%
# net daily return: 0.47%
# cumulative net return so far: 13.99%
#
# day 2023-02-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.17%
# net daily return: -0.17%
# cumulative net return so far: 13.8%
#
# day 2023-02-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 13.8%
#
# day 2023-02-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.17%
# net daily return: -0.17%
# cumulative net return so far: 13.61%
#
# day 2023-02-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.36%
# net daily return: -0.36%
# cumulative net return so far: 13.19%
#
# day 2023-02-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.22%
# net daily return: -0.22%
# cumulative net return so far: 12.94%
#
# day 2023-02-13 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: 13.3%
#
# day 2023-02-14 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.17%
# net daily return: 0.17%
# cumulative net return so far: 13.5%
#
# day 2023-02-15 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.15%
# net daily return: 0.15%
# cumulative net return so far: 13.67%
#
# day 2023-02-16 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.4%
# net daily return: 0.4%
# cumulative net return so far: 14.12%
#
# day 2023-02-17 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.52%
# net daily return: 1.52%
# cumulative net return so far: 15.86%
#
# day 2023-02-21 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.2%
# net daily return: -0.2%
# cumulative net return so far: 15.62%
#
# day 2023-02-22 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.24%
# net daily return: 0.24%
# cumulative net return so far: 15.89%
#
# day 2023-02-23 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.2%
# net daily return: 0.2%
# cumulative net return so far: 16.12%
#
# day 2023-02-24 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.34%
# net daily return: -0.54%
# cumulative net return so far: 15.49%
#
# day 2023-02-27 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.04%
# net daily return: 0.04%
# cumulative net return so far: 15.53%
#
# day 2023-02-28 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.68%
# net daily return: -0.68%
# cumulative net return so far: 14.74%
#
# day 2023-03-01 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 1.51%
# net daily return: 1.51%
# cumulative net return so far: 16.48%
#
# day 2023-03-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.66%
# net daily return: 0.46%
# cumulative net return so far: 17.02%
#
# day 2023-03-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.54%
# net daily return: -0.54%
# cumulative net return so far: 16.39%
#
# day 2023-03-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.02%
# net daily return: -0.02%
# cumulative net return so far: 16.37%
#
# day 2023-03-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.33%
# net daily return: -0.33%
# cumulative net return so far: 15.99%
#
# day 2023-03-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.69%
# net daily return: -0.69%
# cumulative net return so far: 15.18%
#
# day 2023-03-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.02%
# net daily return: 0.02%
# cumulative net return so far: 15.21%
#
# day 2023-03-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.27%
# net daily return: 0.27%
# cumulative net return so far: 15.52%
#
# day 2023-03-13 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.97%
# net daily return: 0.97%
# cumulative net return so far: 16.65%
#
# day 2023-03-14 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.45%
# net daily return: 0.25%
# cumulative net return so far: 16.94%
#
# day 2023-03-15 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.7%
# net daily return: 0.7%
# cumulative net return so far: 17.76%
#
# day 2023-03-16 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.13%
# net daily return: 0.13%
# cumulative net return so far: 17.91%
#
# day 2023-03-17 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.75%
# net daily return: -0.75%
# cumulative net return so far: 17.02%
#
# day 2023-03-20 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: -0.23%
# net daily return: -0.23%
# cumulative net return so far: 16.75%
#
# day 2023-03-21 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.26%
# net daily return: 0.26%
# cumulative net return so far: 17.05%
#
# day 2023-03-22 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.83%
# net daily return: 0.83%
# cumulative net return so far: 18.02%
#
# day 2023-03-23 00:00:00
#
# long position on BHP and short position on RIO
# gross daily return: 0.83%
# net daily return: 0.83%
# cumulative net return so far: 19.0%
#
# day 2023-03-24 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.25%
# net daily return: 0.05%
# cumulative net return so far: 19.06%
#
# day 2023-03-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.67%
# net daily return: -0.67%
# cumulative net return so far: 18.27%
#
# day 2023-03-28 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.76%
# net daily return: -0.76%
# cumulative net return so far: 17.37%
#
# day 2023-03-29 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.54%
# net daily return: -1.54%
# cumulative net return so far: 15.56%
#
# day 2023-03-30 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.11%
# net daily return: -0.11%
# cumulative net return so far: 15.43%
#
# day 2023-03-31 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.2%
# net daily return: 0.2%
# cumulative net return so far: 15.67%
#
# day 2023-04-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.37%
# net daily return: 1.37%
# cumulative net return so far: 17.25%
#
# day 2023-04-04 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.27%
# net daily return: 0.27%
# cumulative net return so far: 17.57%
#
# day 2023-04-05 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.97%
# net daily return: 0.97%
# cumulative net return so far: 18.72%
#
# day 2023-04-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.06%
# net daily return: 0.06%
# cumulative net return so far: 18.79%
#
# day 2023-04-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.36%
# net daily return: -0.36%
# cumulative net return so far: 18.36%
#
# day 2023-04-11 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.25%
# net daily return: 0.25%
# cumulative net return so far: 18.66%
#
# day 2023-04-12 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.18%
# net daily return: 0.18%
# cumulative net return so far: 18.87%
#
# day 2023-04-13 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.1%
# net daily return: -0.1%
# cumulative net return so far: 18.75%
#
# day 2023-04-14 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.01%
# net daily return: 0.01%
# cumulative net return so far: 18.76%
#
# day 2023-04-17 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.21%
# net daily return: -0.21%
# cumulative net return so far: 18.51%
#
# day 2023-04-18 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.74%
# net daily return: -0.74%
# cumulative net return so far: 17.63%
#
# day 2023-04-19 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.48%
# net daily return: 0.48%
# cumulative net return so far: 18.19%
#
# day 2023-04-20 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.81%
# net daily return: -0.81%
# cumulative net return so far: 17.23%
#
# day 2023-04-21 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.82%
# net daily return: -0.82%
# cumulative net return so far: 16.27%
#
# day 2023-04-24 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.18%
# net daily return: -0.18%
# cumulative net return so far: 16.06%
#
# day 2023-04-25 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.92%
# net daily return: -0.92%
# cumulative net return so far: 14.99%
#
# day 2023-04-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.01%
# net daily return: 0.01%
# cumulative net return so far: 15.0%
#
# day 2023-04-27 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.49%
# net daily return: 0.49%
# cumulative net return so far: 15.56%
#
# day 2023-04-28 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.62%
# net daily return: -0.62%
# cumulative net return so far: 14.85%
#
# day 2023-05-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.11%
# net daily return: -0.11%
# cumulative net return so far: 14.72%
#
# day 2023-05-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.97%
# net daily return: -0.97%
# cumulative net return so far: 13.6%
#
# day 2023-05-03 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.82%
# net daily return: -0.82%
# cumulative net return so far: 12.67%
#
# day 2023-05-04 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.92%
# net daily return: -0.92%
# cumulative net return so far: 11.63%
#
# day 2023-05-05 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.18%
# net daily return: 0.18%
# cumulative net return so far: 11.83%
#
# day 2023-05-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.59%
# net daily return: 0.59%
# cumulative net return so far: 12.5%
#
# day 2023-05-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.34%
# net daily return: 0.34%
# cumulative net return so far: 12.88%
#
# day 2023-05-10 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.47%
# net daily return: 0.47%
# cumulative net return so far: 13.41%
#
# day 2023-05-11 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.52%
# net daily return: -0.52%
# cumulative net return so far: 12.81%
#
# day 2023-05-12 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.11%
# net daily return: -0.11%
# cumulative net return so far: 12.69%
#
# day 2023-05-15 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.11%
# net daily return: -0.11%
# cumulative net return so far: 12.56%
#
# day 2023-05-16 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.27%
# net daily return: 0.27%
# cumulative net return so far: 12.86%
#
# day 2023-05-17 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.05%
# net daily return: -0.05%
# cumulative net return so far: 12.8%
#
# day 2023-05-18 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.42%
# net daily return: 0.42%
# cumulative net return so far: 13.27%
#
# day 2023-05-19 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.65%
# net daily return: -0.65%
# cumulative net return so far: 12.53%
#
# day 2023-05-22 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: 12.24%
#
# day 2023-05-23 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.19%
# net daily return: 1.19%
# cumulative net return so far: 13.58%
#
# day 2023-05-24 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.19%
# net daily return: 1.19%
# cumulative net return so far: 14.93%
#
# day 2023-05-25 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.07%
# net daily return: -0.07%
# cumulative net return so far: 14.86%
#
# day 2023-05-26 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.01%
# net daily return: -0.01%
# cumulative net return so far: 14.85%
#
# day 2023-05-30 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: 14.55%
#
# day 2023-05-31 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.66%
# net daily return: 0.66%
# cumulative net return so far: 15.3%
#
# day 2023-06-01 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.64%
# net daily return: -0.64%
# cumulative net return so far: 14.56%
#
# day 2023-06-02 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 1.05%
# net daily return: 1.05%
# cumulative net return so far: 15.76%
#
# day 2023-06-05 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.36%
# net daily return: -0.36%
# cumulative net return so far: 15.34%
#
# day 2023-06-06 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.08%
# net daily return: 0.08%
# cumulative net return so far: 15.44%
#
# day 2023-06-07 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -0.73%
# net daily return: -0.73%
# cumulative net return so far: 14.59%
#
# day 2023-06-08 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.54%
# net daily return: 0.54%
# cumulative net return so far: 15.21%
#
# day 2023-06-09 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: -1.05%
# net daily return: -1.05%
# cumulative net return so far: 14.0%
#
# day 2023-06-12 00:00:00
#
# long position on RIO and short position on BHP
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: 14.0%
